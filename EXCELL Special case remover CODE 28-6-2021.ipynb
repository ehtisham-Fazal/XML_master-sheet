# %% [markdown]
# <h1>Import File<h1>

# %%
import openpyxl
from openpyxl.utils import get_column_letter

# %% [markdown]
# <H4>SELETE SHEET +AS WELL AS SHEET NAME HINT: PLEASE ADD THE FILE IN A PROPER DIRECTORY <H4>

# %%
wb = openpyxl.load_workbook(r'C:\Users\Cloudee\Desktop\AUTO TASK\codefiles\master_list.xlsx')
wb.sheetnames
sheet = wb["June-3"]

# %% [markdown]
# <H4>FIND SINGLE CHARETER AND RETURNS IT<H4>

# %%
def find(s, ch):
	return [i for i, ltr in enumerate(s) if ltr == ch]

# %% [markdown]
# <H4>CLOUMN_TITLE_DICTIONARY<H4>

# %%
activity_title_dic={'I':'gcactivity_login_signatureurl',
                    'M':'gcactivity_loginfail_signatureurl',
                    'Q':'gcactivity_logout_signatureurl',
                    'U':'gcactivity_upload_signatureurl',
                    'Y':'gcactivity_download_signatureurl',
                    'AC':'gcactivity_delete_signatureurl',
                    'AG':'gcactivity_share_signatureurl',
                    'AK':'gcactivity_personal_signatureurl'}

# %% [markdown]
# <h1>MAIN LOGIC<h1>

# %%
def replace_precentage():
    print("______starting______")
    counter=0
    for row in sheet.iter_rows(min_row=2, max_col=55, max_row=3758):
         for cell in row:
            #enter logic here
            str1=str(cell.value)
            indexes = find(str1,"%")
            if len(indexes)>0:
                print("Product ID : "+ str(row[0].value))
                #print(get_column_letter(cell.column))
                my_letter=get_column_letter(cell.column)
                for key, value in activity_title_dic.items():
                    if key == my_letter:
                        print(value)
                        print("")

            str_indx = 0
            new_str = str1
            fin_str = ""
            for i in indexes:
              rpc_string = str1[i:i+3]
              temp1 = new_str[str_indx:i] + "\\x" + rpc_string[1:] + "\\x"
              fin_str = fin_str + temp1
              str_indx = i+3
            if len(indexes)!=0:
              #print("indexes : ", indexes)
              cell.value = fin_str + cell.value[indexes[-1]+3:]
              if str1!=cell.value:
                    counter=counter+1
    print("% replace to/x /x; no of cell replace : "+str(counter))
    print("____!!___!!_ended__!!__!!___")
# Out:
# Product ID : 263
# gcactivity_upload_signatureurl
#
# Product ID : 269
# gcactivity_login_signatureurl
#
# Product ID : 269
# gcactivity_loginfail_signatureurl
#
# Product ID : 287
# gcactivity_personal_signatureurl
#
# Product ID : 306
# gcactivity_logout_signatureurl
#
# Product ID : 359
# gcactivity_login_signatureurl
#
# Product ID : 359
# gcactivity_loginfail_signatureurl
#
# Product ID : 409
# gcactivity_login_signatureurl
#
# Product ID : 409
# gcactivity_loginfail_signatureurl
#
# Product ID : 424
# gcactivity_login_signatureurl
#
# Product ID : 424
# gcactivity_loginfail_signatureurl
#
# Product ID : 662
# gcactivity_login_signatureurl
#
# Product ID : 662
# gcactivity_loginfail_signatureurl
#
# Product ID : 674
# gcactivity_download_signatureurl
#
# Product ID : 699
# gcactivity_login_signatureurl
#
# Product ID : 699
# gcactivity_upload_signatureurl
#
# Product ID : 716
# gcactivity_delete_signatureurl
#
# Product ID : 825
# gcactivity_login_signatureurl
#
# Product ID : 825
# gcactivity_loginfail_signatureurl
#
# Product ID : 1057
# gcactivity_upload_signatureurl
#
# Product ID : 1179
# gcactivity_share_signatureurl
#
# Product ID : 1179
# gcactivity_personal_signatureurl
#
# Product ID : 1185
# gcactivity_login_signatureurl
#
# Product ID : 1207
# gcactivity_login_signatureurl
#
# Product ID : 1207
# gcactivity_loginfail_signatureurl
#
# Product ID : 1383
# gcactivity_login_signatureurl
#
# Product ID : 1460
# gcactivity_login_signatureurl
#
# Product ID : 1460
# gcactivity_loginfail_signatureurl
#
# Product ID : 1472
# gcactivity_login_signatureurl
#
# Product ID : 1472
# gcactivity_loginfail_signatureurl
#
# Product ID : 1593
# gcactivity_personal_signatureurl
#
# Product ID : 1627
# gcactivity_loginfail_signatureurl
#
# Product ID : 1694
# gcactivity_login_signatureurl
#
# Product ID : 1744
# gcactivity_share_signatureurl
#
# Product ID : 1845
# gcactivity_share_signatureurl
#
# Product ID : 1845
# gcactivity_personal_signatureurl
#
# Product ID : 1912
# gcactivity_login_signatureurl
#
# Product ID : 1912
# gcactivity_loginfail_signatureurl
#
# Product ID : 2182
# gcactivity_loginfail_signatureurl
#
# Product ID : 2450
# gcactivity_logout_signatureurl
#
# Product ID : 2760
# gcactivity_share_signatureurl
#
# Product ID : 2760
# gcactivity_personal_signatureurl
#
# Product ID : 2764
# gcactivity_login_signatureurl
#
# Product ID : 2764
# gcactivity_loginfail_signatureurl
#
# Product ID : 2786
# gcactivity_loginfail_signatureurl
#
# Product ID : 2859
# gcactivity_delete_signatureurl
#
# Product ID : 2884
# gcactivity_delete_signatureurl
#
# Product ID : 2975
# gcactivity_delete_signatureurl
#
# Product ID : 3215
# gcactivity_share_signatureurl
#
# Product ID : 3309
# gcactivity_upload_signatureurl
#
# Product ID : 3323
# gcactivity_share_signatureurl
#
# Product ID : 3323
# gcactivity_personal_signatureurl
#
# Product ID : 3500
# gcactivity_login_signatureurl
#
# Product ID : 3528
# gcactivity_delete_signatureurl
#
# Product ID : 3536
# gcactivity_login_signatureurl
#
# Product ID : 3536
# gcactivity_loginfail_signatureurl
#
# Product ID : 3547
# gcactivity_share_signatureurl
#
# Product ID : 3547
# gcactivity_personal_signatureurl
#
# Product ID : 3604
# gcactivity_login_signatureurl
#
# Product ID : 3671
# gcactivity_share_signatureurl
#
# Product ID : 3671
# gcactivity_personal_signatureurl
#
# Product ID : 3795
# gcactivity_login_signatureurl
#
# Product ID : 3795
# gcactivity_loginfail_signatureurl
#
# Product ID : 4017
# gcactivity_personal_signatureurl
#
# Product ID : 4105
# gcactivity_delete_signatureurl
#
# Product ID : 4137
# gcactivity_download_signatureurl
#
# Product ID : 4156
# gcactivity_share_signatureurl
#
# Product ID : 4192
# gcactivity_delete_signatureurl
#
# Product ID : 4363
# gcactivity_login_signatureurl
#
# Product ID : 4469
# gcactivity_login_signatureurl
#
# Product ID : 4469
# gcactivity_loginfail_signatureurl
#
# Product ID : 4472
# gcactivity_download_signatureurl
#
# Product ID : 4612
# gcactivity_login_signatureurl
#
# Product ID : 4612
# gcactivity_loginfail_signatureurl
#
# Product ID : 4623
# gcactivity_share_signatureurl
#
# Product ID : 4734
# gcactivity_share_signatureurl
#
# Product ID : 4734
# gcactivity_personal_signatureurl
#
# Product ID : 4799
# gcactivity_download_signatureurl
#
# Product ID : 4846
# gcactivity_delete_signatureurl
#
# Product ID : 4961
# gcactivity_login_signatureurl
#
# Product ID : 4961
# gcactivity_logout_signatureurl
#
# Product ID : 4961
# gcactivity_download_signatureurl
#
# Product ID : 4961
# gcactivity_delete_signatureurl
#
# Product ID : 5164
# gcactivity_delete_signatureurl
#
# Product ID : 5164
# gcactivity_share_signatureurl
#
# Product ID : 5264
# gcactivity_login_signatureurl
#
# Product ID : 5264
# gcactivity_loginfail_signatureurl
#
# Product ID : 5349
# gcactivity_share_signatureurl
#
# Product ID : 5349
# gcactivity_personal_signatureurl
#
# Product ID : 5353
# gcactivity_delete_signatureurl
#
# Product ID : 5353
# gcactivity_share_signatureurl
#
# Product ID : 5365
# gcactivity_download_signatureurl
#
# Product ID : 5365
# gcactivity_share_signatureurl
#
# Product ID : 5408
# gcactivity_loginfail_signatureurl
#
# Product ID : 5501
# gcactivity_delete_signatureurl
#
# Product ID : 5545
# gcactivity_share_signatureurl
#
# Product ID : 5653
# gcactivity_download_signatureurl
#
# Product ID : 5665
# gcactivity_login_signatureurl
#
# Product ID : 5665
# gcactivity_loginfail_signatureurl
#
# Product ID : 5892
# gcactivity_share_signatureurl
#
# Product ID : 5892
# gcactivity_personal_signatureurl
#
# Product ID : 5926
# gcactivity_login_signatureurl
#
# Product ID : 5926
# gcactivity_loginfail_signatureurl
#
# Product ID : 6126
# gcactivity_login_signatureurl
#
# Product ID : 6247
# gcactivity_share_signatureurl
#
# Product ID : 6247
# gcactivity_personal_signatureurl
#
# Product ID : 6252
# gcactivity_share_signatureurl
#
# Product ID : 6252
# gcactivity_personal_signatureurl
#
# Product ID : 6378
# gcactivity_logout_signatureurl
#
# Product ID : 6378
# gcactivity_delete_signatureurl
#
# Product ID : 6697
# gcactivity_share_signatureurl
#
# Product ID : 6752
# gcactivity_download_signatureurl
#
# Product ID : 7117
# gcactivity_loginfail_signatureurl
#
# Product ID : 7503
# gcactivity_logout_signatureurl
#
# Product ID : 7518
# gcactivity_login_signatureurl
#
# Product ID : 7518
# gcactivity_loginfail_signatureurl
#
# Product ID : 7519
# gcactivity_login_signatureurl
#
# Product ID : 7519
# gcactivity_loginfail_signatureurl
#
# Product ID : 7523
# gcactivity_logout_signatureurl
#
# Product ID : 7792
# gcactivity_share_signatureurl
#
# Product ID : 7991
# gcactivity_delete_signatureurl
#
# Product ID : 8055
# gcactivity_logout_signatureurl
#
# Product ID : 8055
# gcactivity_upload_signatureurl
#
# Product ID : 8289
# gcactivity_login_signatureurl
#
# Product ID : 8289
# gcactivity_loginfail_signatureurl
#
# Product ID : 8313
# gcactivity_share_signatureurl
#
# Product ID : 8313
# gcactivity_personal_signatureurl
#
# Product ID : 8380
# gcactivity_delete_signatureurl
#
# Product ID : 8809
# gcactivity_logout_signatureurl
#
# Product ID : 10504
# gcactivity_upload_signatureurl
#
# Product ID : 10576
# gcactivity_loginfail_signatureurl
#
# Product ID : 10737
# gcactivity_login_signatureurl
#
# Product ID : 10737
# gcactivity_loginfail_signatureurl
#
# Product ID : 10944
# gcactivity_login_signatureurl
#
# Product ID : 10944
# gcactivity_loginfail_signatureurl
#
# Product ID : 12675
# gcactivity_login_signatureurl
#
# Product ID : 12675
# gcactivity_loginfail_signatureurl
#
# Product ID : 13664
# gcactivity_share_signatureurl
#
# Product ID : 13664
# gcactivity_personal_signatureurl
#
# Product ID : 13789
# gcactivity_share_signatureurl
#
# Product ID : 13789
# gcactivity_personal_signatureurl
#
# Product ID : 13944
# gcactivity_share_signatureurl
#
# Product ID : 14124
# gcactivity_login_signatureurl
#
# Product ID : 14124
# gcactivity_loginfail_signatureurl
#
# Product ID : 14281
# gcactivity_login_signatureurl
#
# Product ID : 14332
# gcactivity_login_signatureurl
#
# Product ID : 14342
# gcactivity_upload_signatureurl
#
# Product ID : 14344
# gcactivity_share_signatureurl
#
# Product ID : 14344
# gcactivity_personal_signatureurl
#
# Product ID : 14410
# gcactivity_upload_signatureurl
#
# Product ID : 14410
# gcactivity_share_signatureurl
#
# Product ID : 14410
# gcactivity_personal_signatureurl
#
# Product ID : 14535
# gcactivity_upload_signatureurl
#
# Product ID : 14775
# gcactivity_upload_signatureurl
#
# Product ID : 14863
# gcactivity_logout_signatureurl
#
# Product ID : 15061
# gcactivity_loginfail_signatureurl
#
# Product ID : 15086
# gcactivity_login_signatureurl
#
# Product ID : 15086
# gcactivity_loginfail_signatureurl
#
# Product ID : 15202
# gcactivity_download_signatureurl
#
# Product ID : 15232
# gcactivity_download_signatureurl
#
# Product ID : 15380
# gcactivity_share_signatureurl
#
# Product ID : 15467
# gcactivity_login_signatureurl
#
# Product ID : 15467
# gcactivity_loginfail_signatureurl
#
# Product ID : 15518
# gcactivity_share_signatureurl
#
# Product ID : 15518
# gcactivity_personal_signatureurl
#
# Product ID : 15605
# gcactivity_login_signatureurl
#
# Product ID : 15605
# gcactivity_loginfail_signatureurl
#
# Product ID : 15680
# gcactivity_delete_signatureurl
#
# Product ID : 15697
# gcactivity_login_signatureurl
#
# Product ID : 15697
# gcactivity_loginfail_signatureurl
#
# Product ID : 15890
# gcactivity_logout_signatureurl
#
# Product ID : 15945
# gcactivity_login_signatureurl
#
# Product ID : 15945
# gcactivity_loginfail_signatureurl
#
# Product ID : 16112
# Product ID : 16112
# Product ID : 16259
# gcactivity_share_signatureurl
#
# Product ID : 16555
# gcactivity_login_signatureurl
#
# Product ID : 16555
# gcactivity_loginfail_signatureurl
#
# Product ID : 16565
# gcactivity_login_signatureurl
#
# Product ID : 16565
# gcactivity_loginfail_signatureurl
#
# Product ID : 16717
# gcactivity_download_signatureurl
#
# Product ID : 16759
# gcactivity_login_signatureurl
#
# Product ID : 16759
# gcactivity_loginfail_signatureurl
#
# Product ID : 17023
# gcactivity_login_signatureurl
#
# Product ID : 17023
# gcactivity_loginfail_signatureurl
#
# Product ID : 17054
# gcactivity_login_signatureurl
#
# Product ID : 17054
# gcactivity_loginfail_signatureurl
#
# Product ID : 17135
# gcactivity_share_signatureurl
#
# Product ID : 17202
# gcactivity_login_signatureurl
#
# Product ID : 17202
# gcactivity_loginfail_signatureurl
#
# Product ID : 17247
# gcactivity_login_signatureurl
#
# Product ID : 17247
# gcactivity_loginfail_signatureurl
#
# Product ID : 17264
# gcactivity_login_signatureurl
#
# Product ID : 17264
# gcactivity_loginfail_signatureurl
#
# Product ID : 18195
# gcactivity_logout_signatureurl
#
# Product ID : 18364
# gcactivity_share_signatureurl
#
# Product ID : 18389
# gcactivity_delete_signatureurl
#
# Product ID : 18414
# gcactivity_share_signatureurl
#
# Product ID : 18574
# gcactivity_upload_signatureurl
#
# Product ID : 18579
# gcactivity_logout_signatureurl
#
# Product ID : 18582
# gcactivity_login_signatureurl
#
# Product ID : 18582
# gcactivity_loginfail_signatureurl
#
# Product ID : 18582
# gcactivity_upload_signatureurl
#
# Product ID : 18598
# gcactivity_share_signatureurl
#
# Product ID : 18598
# gcactivity_personal_signatureurl
#
# Product ID : 18662
# gcactivity_login_signatureurl
#
# Product ID : 18662
# gcactivity_loginfail_signatureurl
#
# Product ID : 18667
# gcactivity_logout_signatureurl
#
# Product ID : 18667
# gcactivity_download_signatureurl
#
# Product ID : 18667
# gcactivity_delete_signatureurl
#
# Product ID : 18720
# gcactivity_logout_signatureurl
#
# Product ID : 18742
# gcactivity_upload_signatureurl
#
# Product ID : 18742
# gcactivity_delete_signatureurl
#
# Product ID : 18742
# gcactivity_share_signatureurl
#
# Product ID : 18742
# gcactivity_personal_signatureurl
#
# Product ID : 18927
# gcactivity_share_signatureurl
#
# Product ID : 18931
# gcactivity_share_signatureurl
#
# Product ID : 18991
# gcactivity_share_signatureurl
#
# Product ID : 19038
# gcactivity_login_signatureurl
#
# Product ID : 19038
# gcactivity_upload_signatureurl
#
# Product ID : 19038
# gcactivity_delete_signatureurl
#
# Product ID : 19076
# gcactivity_loginfail_signatureurl
#
# Product ID : 19298
# gcactivity_login_signatureurl
#
# Product ID : 19298
# gcactivity_loginfail_signatureurl
#
# Product ID : 19302
# gcactivity_download_signatureurl
#
# Product ID : 19305
# gcactivity_delete_signatureurl
#
# Product ID : 19305
# gcactivity_share_signatureurl
#
# Product ID : 19427
# gcactivity_share_signatureurl
#
# Product ID : 19474
# gcactivity_download_signatureurl
#
# Product ID : 19496
# gcactivity_download_signatureurl
# Product ID : 19505
# gcactivity_login_signatureurl
#
# Product ID : 19505
# gcactivity_loginfail_signatureurl
#
# Product ID : 19652
# gcactivity_login_signatureurl
#
# Product ID : 19652
# gcactivity_loginfail_signatureurl
#
# Product ID : 19711
# gcactivity_login_signatureurl
#
# Product ID : 19711
# gcactivity_loginfail_signatureurl
#
# Product ID : 19735
# gcactivity_delete_signatureurl
#
# Product ID : 19763
# gcactivity_share_signatureurl
#
# Product ID : 19918
# gcactivity_loginfail_signatureurl
#
# Product ID : 20042
# gcactivity_delete_signatureurl
#
# Product ID : 20060
# gcactivity_login_signatureurl
#
# Product ID : 20060
# gcactivity_loginfail_signatureurl
#
# Product ID : 20198
# gcactivity_login_signatureurl
#
# Product ID : 20198
# gcactivity_loginfail_signatureurl
#
# Product ID : 20298
# gcactivity_personal_signatureurl
#
# Product ID : 20644
# gcactivity_download_signatureurl
#
# Product ID : 20659
# gcactivity_loginfail_signatureurl
#
# Product ID : 20927
# gcactivity_login_signatureurl
#
# Product ID : 20927
# gcactivity_loginfail_signatureurl
#
# Product ID : 21168
# gcactivity_login_signatureurl
#
# Product ID : 21264
# gcactivity_personal_signatureurl
#
# Product ID : 21861
# gcactivity_delete_signatureurl
#
# Product ID : 21861
# gcactivity_share_signatureurl
#
# Product ID : 21861
# gcactivity_personal_signatureurl
#
# Product ID : 22336
# gcactivity_download_signatureurl
#
# Product ID : 22451
# gcactivity_share_signatureurl
#
# Product ID : 22651
# gcactivity_login_signatureurl
#
# Product ID : 22651
# gcactivity_loginfail_signatureurl
#
# Product ID : 22674
# gcactivity_share_signatureurl
#
# Product ID : 22877
# gcactivity_login_signatureurl
#
# Product ID : 22877
# gcactivity_loginfail_signatureurl
#
# Product ID : 25279
# gcactivity_download_signatureurl
#
# Product ID : 25322
# gcactivity_download_signatureurl
#
# Product ID : 25679
# gcactivity_delete_signatureurl
#
# Product ID : 26525
# gcactivity_logout_signatureurl
#
# Product ID : 27338
# gcactivity_login_signatureurl
#
# Product ID : 27338
# gcactivity_loginfail_signatureurl
#
# Product ID : 27574
# gcactivity_share_signatureurl
#
# Product ID : 27679
# gcactivity_download_signatureurl
#
# Product ID : 27769
# gcactivity_login_signatureurl
#
# Product ID : 27769
# gcactivity_loginfail_signatureurl
#
# Product ID : 29184
# gcactivity_login_signatureurl
#
# Product ID : 29184
# gcactivity_loginfail_signatureurl
#
# Product ID : 29406
# gcactivity_login_signatureurl
#
# Product ID : 29406
# gcactivity_loginfail_signatureurl
#
# Product ID : 30363
# gcactivity_logout_signatureurl
#
# Product ID : 32517
# gcactivity_personal_signatureurl
#
# Product ID : 34407
# gcactivity_login_signatureurl
#
# Product ID : 34407
# gcactivity_loginfail_signatureurl
#
# Product ID : 34421
# gcactivity_download_signatureurl
#
# Product ID : 36094
# gcactivity_login_signatureurl
#
# Product ID : 36094
# gcactivity_loginfail_signatureurl
#
# Product ID : 36096
# gcactivity_share_signatureurl
#
# Product ID : 36096
# gcactivity_personal_signatureurl
#
# Product ID : 39326
# gcactivity_login_signatureurl
#
# Product ID : 39326
# gcactivity_loginfail_signatureurl
#
# Product ID : 39438
# gcactivity_login_signatureurl
#
# Product ID : 39438
# gcactivity_loginfail_signatureurl
#
# Product ID : 39452
# gcactivity_login_signatureurl
#
# Product ID : 39452
# gcactivity_loginfail_signatureurl
#
# Product ID : 39486
# gcactivity_delete_signatureurl
#
# Product ID : 39511
# gcactivity_login_signatureurl
#
# Product ID : 39511
# gcactivity_loginfail_signatureurl
#
# Product ID : 39511
# gcactivity_upload_signatureurl
#
# Product ID : 39524
# gcactivity_download_signatureurl
#
# Product ID : 39724
# gcactivity_logout_signatureurl
#
# Product ID : 40004
# gcactivity_delete_signatureurl
#
# Product ID : 40552
# gcactivity_login_signatureurl
#
# Product ID : 40552
# gcactivity_loginfail_signatureurl
#
# Product ID : 40552
# gcactivity_logout_signatureurl
#
# Product ID : 40969
# gcactivity_download_signatureurl
#
# Product ID : 41039
# gcactivity_login_signatureurl
#
# Product ID : 41039
# gcactivity_loginfail_signatureurl
#
# Product ID : 41064
# gcactivity_share_signatureurl
#
# Product ID : 41064
# gcactivity_personal_signatureurl
#
# Product ID : 41250
# gcactivity_login_signatureurl
#
# Product ID : 41250
# gcactivity_loginfail_signatureurl
#
# Product ID : 41368
# gcactivity_login_signatureurl
#
# Product ID : 41368
# gcactivity_loginfail_signatureurl
#
# Product ID : 41481
# gcactivity_personal_signatureurl
#
# Product ID : 41483
# gcactivity_share_signatureurl
#
# Product ID : 41659
# gcactivity_login_signatureurl
#
# Product ID : 41659
# gcactivity_loginfail_signatureurl
#
# Product ID : 41752
# gcactivity_download_signatureurl
#
# Product ID : 41752
# gcactivity_delete_signatureurl
#
# Product ID : 41755
# gcactivity_delete_signatureurl
#
# Product ID : 41755
# gcactivity_share_signatureurl
#
# Product ID : 42248
# gcactivity_share_signatureurl
#
# Product ID : 42292
# gcactivity_share_signatureurl
#
# Product ID : 42970
# gcactivity_share_signatureurl
#
# Product ID : 43811
# gcactivity_share_signatureurl
#
# Product ID : 43811
# gcactivity_personal_signatureurl
#
# Product ID : 44599
# gcactivity_download_signatureurl
#
# Product ID : 44599
# gcactivity_delete_signatureurl
#
# Product ID : 46085
# gcactivity_loginfail_signatureurl
#
# Product ID : 47019
# gcactivity_share_signatureurl
#
# Product ID : 47227
# gcactivity_login_signatureurl
#
# Product ID : 47227
# gcactivity_loginfail_signatureurl
#
# Product ID : 48114
# gcactivity_login_signatureurl
#
# Product ID : 48114
# gcactivity_loginfail_signatureurl
#
# Product ID : 48301
# gcactivity_share_signatureurl
#
# Product ID : 48407
# gcactivity_login_signatureurl
#
# Product ID : 48407
# gcactivity_loginfail_signatureurl
#
# Product ID : 48448
# gcactivity_login_signatureurl
#
# Product ID : 48448
# gcactivity_loginfail_signatureurl
#
# Product ID : 48448
# gcactivity_upload_signatureurl
#
# Product ID : 48912
# gcactivity_login_signatureurl
#
# Product ID : 48912
# gcactivity_loginfail_signatureurl
#
# Product ID : 49502
# gcactivity_upload_signatureurl
#
# Product ID : 49502
# gcactivity_delete_signatureurl
#
# Product ID : 49879
# gcactivity_share_signatureurl
#
# Product ID : 49879
# gcactivity_personal_signatureurl
#
# Product ID : 49885
# gcactivity_personal_signatureurl
#
# Product ID : 50804
# gcactivity_delete_signatureurl
#
# Product ID : 50804
# gcactivity_share_signatureurl
#
# Product ID : 52240
# gcactivity_login_signatureurl
#
# Product ID : 52240
# gcactivity_loginfail_signatureurl
#
# Product ID : 52244
# gcactivity_login_signatureurl
#
# Product ID : 52244
# gcactivity_loginfail_signatureurl
#
# Product ID : 52865
# gcactivity_delete_signatureurl
#
# Product ID : 52908
# gcactivity_login_signatureurl
#
# Product ID : 52908
# gcactivity_loginfail_signatureurl
#
# Product ID : 52908
# gcactivity_share_signatureurl
#
# Product ID : 52992
# gcactivity_share_signatureurl
#
# Product ID : 53008
# gcactivity_login_signatureurl
#
# Product ID : 53008
# gcactivity_loginfail_signatureurl
#
# Product ID : 53248
# gcactivity_login_signatureurl
#
# Product ID : 53248
# gcactivity_loginfail_signatureurl
#
# Product ID : 53267
# gcactivity_download_signatureurl
#
# Product ID : 53461
# gcactivity_share_signatureurl
#
# Product ID : 53484
# gcactivity_upload_signatureurl
#
# Product ID : 53980
# gcactivity_loginfail_signatureurl
#
# Product ID : 54000
# gcactivity_upload_signatureurl
#
# Product ID : 54398
# gcactivity_upload_signatureurl
#
# Product ID : 54398
# gcactivity_delete_signatureurl
#
# Product ID : 54398
# gcactivity_share_signatureurl
#
# Product ID : 55484
# gcactivity_delete_signatureurl
#
# Product ID : 55713
# gcactivity_login_signatureurl
#
# Product ID : 55713
# gcactivity_loginfail_signatureurl
#
# Product ID : 56437
# gcactivity_personal_signatureurl
#
# Product ID : 59258
# gcactivity_login_signatureurl
#
# Product ID : 59258
# gcactivity_loginfail_signatureurl
#
# Product ID : 59530
# gcactivity_login_signatureurl
#
# Product ID : 59530
# gcactivity_loginfail_signatureurl
#
# Product ID : 59700
# gcactivity_login_signatureurl
#
# Product ID : 59700
# gcactivity_loginfail_signatureurl
#
# Product ID : 60210
# gcactivity_login_signatureurl
#
# Product ID : 60210
# gcactivity_loginfail_signatureurl
#
# Product ID : 60515
# gcactivity_login_signatureurl
#
# Product ID : 60515
# gcactivity_loginfail_signatureurl
#
# Product ID : 61708
# gcactivity_login_signatureurl
#
# Product ID : 61708
# gcactivity_loginfail_signatureurl
#
# Product ID : 63581
# gcactivity_login_signatureurl
#
# Product ID : 63581
# gcactivity_loginfail_signatureurl
#
# Product ID : 65809
# gcactivity_login_signatureurl
#
# Product ID : 66642
# gcactivity_download_signatureurl
#
# Product ID : 67020
# gcactivity_login_signatureurl
#
# Product ID : 67020
# gcactivity_loginfail_signatureurl
#
# Product ID : 67213
# gcactivity_share_signatureurl
#
# Product ID : 67490
# gcactivity_login_signatureurl
#
# Product ID : 67490
# gcactivity_loginfail_signatureurl
#
# Product ID : 67498
# gcactivity_upload_signatureurl
#
# Product ID : 68287
# gcactivity_share_signatureurl
#
# Product ID : 68287
# gcactivity_personal_signatureurl
#
# Product ID : 68342
# gcactivity_login_signatureurl
#
# Product ID : 68578
# gcactivity_delete_signatureurl
#
# Product ID : 68578
# gcactivity_personal_signatureurl
#
# Product ID : 68827
# gcactivity_upload_signatureurl
#
# Product ID : 70617
# gcactivity_share_signatureurl
#
# Product ID : 70617
# gcactivity_personal_signatureurl
# Product ID : 74220
# gcactivity_login_signatureurl
#
# Product ID : 74220
# gcactivity_loginfail_signatureurl
#
# Product ID : 74264
# gcactivity_loginfail_signatureurl
#
# Product ID : 74264
# gcactivity_share_signatureurl
#
# Product ID : 74350
# gcactivity_login_signatureurl
#
# Product ID : 74350
# gcactivity_loginfail_signatureurl
#
# Product ID : 74543
# gcactivity_login_signatureurl
#
# Product ID : 74543
# gcactivity_loginfail_signatureurl
#
# Product ID : 75250
# gcactivity_logout_signatureurl
#
# Product ID : 75459
# gcactivity_download_signatureurl
#
# Product ID : 77600
# gcactivity_login_signatureurl
#
# Product ID : 77600
# gcactivity_loginfail_signatureurl
#
# Product ID : 79199
# gcactivity_upload_signatureurl
#
# Product ID : 80764
# gcactivity_login_signatureurl
#
# Product ID : 80764
# gcactivity_loginfail_signatureurl
#
# Product ID : 81033
# gcactivity_login_signatureurl
#
# Product ID : 81033
# gcactivity_loginfail_signatureurl
#
# Product ID : 82391
# gcactivity_loginfail_signatureurl
#
# Product ID : 82688
# gcactivity_share_signatureurl
#
# Product ID : 84690
# gcactivity_share_signatureurl
#
# Product ID : 84690
# gcactivity_personal_signatureurl
#
# Product ID : 85113
# gcactivity_upload_signatureurl
#
# Product ID : 87447
# gcactivity_login_signatureurl
#
# Product ID : 87447
# gcactivity_loginfail_signatureurl
#
# Product ID : 87919
# gcactivity_share_signatureurl
#
# Product ID : 87919
# gcactivity_personal_signatureurl
#
# Product ID : 89852
# gcactivity_login_signatureurl
#
# Product ID : 89852
# gcactivity_loginfail_signatureurl
#
# Product ID : 91077
# gcactivity_login_signatureurl
#
# Product ID : 91077
# gcactivity_loginfail_signatureurl
#
# Product ID : 92718
# gcactivity_download_signatureurl
#
# Product ID : 94520
# gcactivity_share_signatureurl
#
# Product ID : 94769
# gcactivity_login_signatureurl
#
# Product ID : 94769
# gcactivity_loginfail_signatureurl
#
# Product ID : 96721
# gcactivity_loginfail_signatureurl
#
# Product ID : 97641
# gcactivity_logout_signatureurl
#
# Product ID : 97777
# gcactivity_logout_signatureurl
#
# Product ID : 98021
# gcactivity_login_signatureurl
#
# Product ID : 98021
# gcactivity_loginfail_signatureurl
#
# Product ID : 98753
# gcactivity_login_signatureurl
#
# Product ID : 98753
# gcactivity_loginfail_signatureurl
#
# Product ID : 100413
# gcactivity_share_signatureurl
#
# Product ID : 100464
# gcactivity_login_signatureurl
#
# Product ID : 100793
# gcactivity_logout_signatureurl
#
# Product ID : 101292
# gcactivity_login_signatureurl
#
# Product ID : 101292
# gcactivity_loginfail_signatureurl
#
# Product ID : 101640
# gcactivity_share_signatureurl
#
# Product ID : 104473
# gcactivity_logout_signatureurl
#
# Product ID : 105015
# gcactivity_loginfail_signatureurl
#
# Product ID : 105098
# gcactivity_login_signatureurl
#
# Product ID : 105098
# gcactivity_loginfail_signatureurl
#
# Product ID : 106533
# gcactivity_login_signatureurl
#
# Product ID : 106533
# gcactivity_loginfail_signatureurl
#
# Product ID : 111111
# gcactivity_login_signatureurl
#
# Product ID : 111111
# gcactivity_loginfail_signatureurl
#
# Product ID : 111111
# gcactivity_download_signatureurl
#
# Product ID : 116142
# gcactivity_delete_signatureurl
#
# Product ID : 119497
# gcactivity_loginfail_signatureurl

# %% [markdown]
# <h1>Saving data to  new file in the same directory <h1>

# %%
wb.save('new_EHTISHAM3210123.xlsx')

# %% [markdown]
# <h1>THE END<h1>
