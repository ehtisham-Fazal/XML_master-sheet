# %% [markdown]
# <h1>HTTP REQ ,HOST, SIGNATURE_URL ACTIVITIES BALANCE CHECKER<h1>

# %%
import pandas as pd
import json
from pprint import pprint
import numpy as np
# FUNCTION FOR GETTING UNIQUE VALUES IF ALL ARE SAME
def allthesame(l):
    return np.unique(l).shape[0]<=1
# READ FILE FROM LOCATION
data = pd.read_excel (r'C:\Users\Cloudee\Desktop\AUTO TASK\AMAZON SPECIAL CASE BALANCE CEHCK.xlsx')
#ARRAY USED  FOR ENETRING INTO ACTIVITY COLUMN ONLY
columns = ['gcactivity_login','gcactivity_loginfail', 'gcactivity_logout', 'gcactivity_upload', 'gcactivity_download',
'gcactivity_delete', 'gcactivity_share', 'gcactivity_readonly']
#ARRAY FOR ENTERING ONLY THREE COLOUMN WHOSE VALUES ARE REQUIRED
activity = ['_isfirsthttprequest', '_scope', '_signatureurl']



df = pd.DataFrame(data )



counter = 0
empto=[]
new_list = []
result_dict = {}
for index, row in df.iterrows():
	# trying to rename each Name to ABC
    for col in columns:
        empto=[]
        for act in activity :
            
            counter = 0
#             #print(col+act)
#             #print(row[col+act])
###### BELOW CONDITON FOR GOINF INTO SPECFIC COLOUMN CELL CALLING BOTH ABOVE ARRAY AMD GETTING VAUES OF CELL
            if "nan" not in str(row[col+act]) and "!!!!" in str(row[col+act]):
            
                splited=str(row[col+act]).split('!!!!')
                #print(len(splited))
                #print(splited)
                counter=len(splited)
            elif len(str(row[col+act]))==0:
                
                counter=0
            elif len(str(row[col+act]))>0 :
                counter=0
            empto.append(counter)
          
        
        #print(empto)
        if allthesame(empto):
            pass
        else :
            print("condition not true")
            print("Product ID : "+ str(row[0])+" "+str(col+act))
            print()
# Out:
# condition not true
# Product ID : 263 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 705 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 1392 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 1488 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 2748 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 2829 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 2996 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 4156 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 4278 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 5355 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 5483 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 6781 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 6791 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 8214 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 10738 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 13943 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 14030 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 14868 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 14925 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 18782 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 19895 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 20143 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20266 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 20266 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 20745 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 22321 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 25557 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 27540 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 27590 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 27726 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 33457 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 38135 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 39629 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 39780 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 41064 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 42877 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 49485 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 51958 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 52992 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 54617 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 56950 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 56950 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 57253 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 58047 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 65276 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 66253 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 67759 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 75140 gcactivity_login_signatureurl
#
# condition not true
# Product ID : 75140 gcactivity_loginfail_signatureurl
#
# condition not true
# Product ID : 75140 gcactivity_logout_signatureurl
#
# condition not true
# Product ID : 75262 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 87394 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 87922 gcactivity_login_signatureurl
#
# condition not true
# Product ID : 87922 gcactivity_loginfail_signatureurl
#
# condition not true
# Product ID : 87922 gcactivity_logout_signatureurl
#
# condition not true
# Product ID : 92240 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 99175 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 100793 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 20000056 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20000200 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20000450 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 20000450 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 20000575 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20000819 gcactivity_upload_signatureurl

# %%
# Out:
# condition not true
# Product ID : 263 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 705 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 1392 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 1488 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 2651 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 2748 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 2829 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 2996 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 4156 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 4278 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 5355 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 5483 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 6781 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 6791 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 8214 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 10738 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 13943 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 14030 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 14868 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 14925 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 18782 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 19895 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 20143 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20266 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 20266 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 20745 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 22321 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 25557 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 27540 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 27590 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 27726 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 33457 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 38135 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 39629 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 39780 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 41064 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 42877 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 49485 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 51958 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 52992 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 54617 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 56950 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 56950 gcactivity_share_signatureurl
#
# condition not true
# Product ID : 57253 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 58047 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 65276 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 66253 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 67759 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 75140 gcactivity_login_signatureurl
#
# condition not true
# Product ID : 75140 gcactivity_loginfail_signatureurl
#
# condition not true
# Product ID : 75140 gcactivity_logout_signatureurl
#
# condition not true
# Product ID : 75262 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 87394 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 87922 gcactivity_login_signatureurl
#
# condition not true
# Product ID : 87922 gcactivity_loginfail_signatureurl
#
# condition not true
# Product ID : 87922 gcactivity_logout_signatureurl
#
# condition not true
# Product ID : 92240 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 99175 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 100793 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 20000056 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20000200 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20000450 gcactivity_download_signatureurl
#
# condition not true
# Product ID : 20000450 gcactivity_delete_signatureurl
#
# condition not true
# Product ID : 20000575 gcactivity_upload_signatureurl
#
# condition not true
# Product ID : 20000819 gcactivity_upload_signatureurl
